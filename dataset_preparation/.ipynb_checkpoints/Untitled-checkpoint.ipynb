# %%
import pandas as pd

# %%
df = pd.read_csv('list_choices_all_languages.csv')
df.head()
# Out:
#         TRACKER  \
# 0  Not Done - 2
# 1    Done - 441
# 2   No Key - 31
# 3        Status
# 4           NaN
#
#   MADE A COPY TO SERVE AS A CHECK LIST [COPY AS OF 10/03/2023 10:11AM  \
# 0  Cells for questions that are still incomplete ...
# 1                                                NaN
# 2                                                NaN
# 3                               Location in Database
# 4                                         Collection
#
#   Unnamed: 2                                         Unnamed: 3  \
# 0        NaN  Make sure to apply corrections from this check...
# 1        NaN                                                NaN
# 2        NaN                                                NaN
# 3        NaN                                             Item #
# 4   Document                                                NaN
#
#                         Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# ...

# %%
df[3:]
# Out:
#     TRACKER  \
# 3    Status
# 4       NaN
# 5      Done
# 6      Done
# 7      Done
# ..      ...
# 483    Done
# 484    Done
# 485    Done
# 486    Done
# 487    Done
#
#     MADE A COPY TO SERVE AS A CHECK LIST [COPY AS OF 10/03/2023 10:11AM  \
# 3                                 Location in Database
# 4                                           Collection
# 5                                       allergy-module
# 6                                                  NaN
# 7                                                  NaN
# ..                                                 ...
# 483                                                NaN
# 484                                                NaN
# 485                                                NaN
# 486                                                NaN
# 487                                                NaN
#
#                Unnamed: 2 Unnamed: 3                       Unnamed: 4  \
# ...
